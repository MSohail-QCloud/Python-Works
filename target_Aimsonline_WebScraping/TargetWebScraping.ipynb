# %%
#! pip3 install selenium

# %%
from bs4 import BeautifulSoup

# %%
import requests
dpci="025-03-0027"
#link="https://www.target.com/s?searchTerm="+dpci
link="https://www.target.com/p/women-s-active-striped-compression-2pk-knee-high-athletic-socks-all-in-motion-4-10/-/A-78803757?preselect=78463450#lnk=sametab"
page = requests.get(link)#https://www.target.com/s?searchTerm=025-03-0027
page
# Out:
# <Response [200]>

# %%
#r=requests.get(url)
#htmlContent=r.content
#print(htmlContent)
htmlpage=page.content
#print(htmlpage.prett)

# %%
print(link)
# Out:
# https://www.target.com/p/women-s-active-striped-compression-2pk-knee-high-athletic-socks-all-in-motion-4-10/-/A-78803757?preselect=78463450#lnk=sametab

# %%
soup = BeautifulSoup(htmlpage, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
textabc=soup.get_text()

# %%
print(textabc)
# Out:
#
#
#
#
#
#
#
#
#
#
# ...

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

webpage = r"https://www.target.com/" # edit me
searchterm = "025-03-0027" # dpci 025-03-0027

#driver = webdriver.Chrome()
page=driver.get(webpage)
html=page.content
soup = BeautifulSoup(htmlpage, 'lxml')
#sbox = driver.find_element_by_class_name("searchinputform")
#sbox = driver.findElement(By.LocatorStrategy("searchTerm"));
#sbox.send_keys(searchterm)

#submit = driver.find_element_by_class_name("SearchInputButton-sc-1opoijs-0 eOzuAz") #SearchInputButton-sc-1opoijs-0 eOzuAz
#submit.click()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/96.0.4664.45/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Muhammad Sohail\.wdm\drivers\chromedriver\win32\96.0.4664.45]
# <ipython-input-59-6949b5e64dc7>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-6949b5e64dc7> in <module>
#       9 #driver = webdriver.Chrome()
#      10 page=driver.get(webpage)
# ---> 11 html=page.content
#      12 html
#      13 #sbox = driver.find_element_by_class_name("searchinputform")
#
# ...

# %%
#pip install webdriver-manager --user
# Out:
# ...
#   Using cached webdriver_manager-3.5.2-py2.py3-none-any.whl (17 kB)
# ...
#   Using cached configparser-5.1.0-py3-none-any.whl (19 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST chromedriver version for 96.0.4664 google-chrome
# Driver [C:\Users\Muhammad Sohail\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache
# <ipython-input-2-0987a487086c>:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
html = BeautifulSoup(page.text, 'html.parser')
articles = html.select('a.post-card')

for article in articles:

    title = article.select('.card-title')[0].get_text()
    excerpt = article.select('.card-text')[0].get_text()
    pub_date = article.select('.card-footer small')[0].get_text()

    my_data.append({"title": title, "excerpt": excerpt, "pub_date": pub_date})

pprint(my_data)

# %% [markdown]
# #!/usr/bin/python3
# #second way
# import requests
#
# #url = 'https://notes.ayushsharma.in/technology'
# url='https://www.target.com/'
# data = requests.get(url)
#
# print(data.text)

# %%
with open("https://www.target.com/") as fp:
    soup = BeautifulSoup(fp, 'html.parser')

#soup = BeautifulSoup("<html>a web page</html>", 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-ba4524c6746d> in <module>
# ----> 1 with open("https://www.target.com/") as fp:
#       2     soup = BeautifulSoup(fp, 'html.parser')
#       3
#       4 #soup = BeautifulSoup("<html>a web page</html>", 'html.parser')
#
# OSError: [Errno 22] Invalid argument: 'https://www.target.com/'

# %%
print(soup)
# Out:
# <html>a web page</html>

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>', 'html.parser')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %%
tag = BeautifulSoup('<b id="boldest">bold</b>', 'html.parser').b
tag['id']
# Out:
# 'boldest'

# %%
tag.attrs
# Out:
# {'id': 'boldest'}

# %%
from bs4 import CData
cdata = CData("A CDATA block")
Comment.replace_with(cdata)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-83d76731ecd8> in <module>
#       1 from bs4 import CData
#       2 cdata = CData("A CDATA block")
# ----> 3 Comment.replace_with(cdata)
#
# NameError: name 'Comment' is not defined

# %%
html_doc = """
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
print(soup)
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
soup.head()
# Out:
# [<title>The Dormouse's story</title>]

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url="https://codewithharry.com"

# %%
r=requests.get(url)
htmlContent=r.content
print(htmlContent)
# Out:
# b'<!DOCTYPE html><html lang="en"><head>\n  <meta charset="utf-8">\n  <title>Home - CodeWithHarry</title>\n  <base href="/">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <link rel="icon" type="image/x-icon" href="favicon.ico">\n  <link rel="preconnect" href="https://fonts.gstatic.com">\n  <style type="text/css">@font-face{font-family:\'Roboto\';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmSU5fCRc4AMP6lbBP.woff2) format(\'woff2\');unicode-range:U+0460-052F, U+1C80-1C88, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/roboto/v27/KFOlCnqEu92Fr1MmSU5fABc4AMP6lbBP.woff2) format(\'woff2\');unicode-range:U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/robo
# ...

# %%
#parse html
soup=BeautifulSoup(htmlContent,'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>Home - CodeWithHarry</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# ...

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>Home - CodeWithHarry</title>
# <base href="/"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://fonts.gstatic.com" rel="preconnect"/>
# ...
